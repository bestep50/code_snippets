# %% [markdown]
# <a href="https://colab.research.google.com/github/bestep50/code_snippets/blob/master/notebooks/ultimate_rvc_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab for [Ultimate RVC](https://github.com/JackismyShephard/ultimate-rvc)
#
# This Colab notebook will **help** you if you don’t have a GPU or if your PC isn’t very powerful.
#
# Simply click `Runtime` in the top navigation bar and `Run all`. Wait for the output of the final cell to show the public gradio url and click on it.
#
# NOTE: If Ultimate RVC is running too slowly with the default sharing method (gradio), consider instead selecting "ngrok" as sharing method.
# This method requires supplying an access token, which you can find on [ngrok](https://ngrok.com/) after creating a personal account.
# The ngrok link output in the final cell will lead you to a new site which will redirect you to Ultimate RVC.

# %%
# @title 0: Initialize notebook
# %pip install ipython-autotime pyngrok
# %load_ext autotime

import codecs
import os
import time
from pathlib import Path
from urllib import request

import ipywidgets as widgets
from IPython.display import clear_output
from IPython.display import display as i_display
from pyngrok import ngrok

clear_output()
# Out:
# time: 85 ms (started: 2026-02-10 15:27:17 +00:00)

# %%
# @title 1: Clone repository
cloneing = codecs.decode(
    "uggcf://tvguho.pbz/WnpxvfzlFurcuneq/hygvzngr-eip.tvg",
    "rot_13",
)

# !git clone $cloneing HRVC
# %cd /content/HRVC
clear_output()
# Out:
# time: 2.74 s (started: 2026-02-10 15:27:17 +00:00)

# %%
# @title 2: Install dependencies

light = codecs.decode("uggcf://nfgeny.fu/hi/0.9.11/vafgnyy.fu", "rot_13")
inits = codecs.decode("./fep/hygvzngr_eip/pber/znva.cl", "rot_13")
prerelease = "--prerelease if-necessary-or-explicit"

# !apt install -y python3-dev unzip
# !curl -LsSf $light | sh

os.environ["URVC_CONSOLE_LOG_LEVEL"] = "WARNING"

# !uv run -q $prerelease $inits
# !uv add $prerelease matplotlib-inline==0.1.7
clear_output()
# Out:
# time: 4min 49s (started: 2026-02-10 15:27:20 +00:00)

# %%
# @title 3: Run Ultimate RVC
# @markdown  #### Choose a sharing method:

method = "gradio"  # @param ["gradio",  "ngrok", "cloudflared","localtunnel"]
ngrok_token = ""  # @param {type:"string"}
runpice = codecs.decode("./fep/hygvzngr_eip/jro/znva.cl", "rot_13")

if method == "gradio":
    # !uv run $prerelease $runpice --share
elif method == "ngrok":
    try:
        ngrok.set_auth_token(ngrok_token)
        ngrok.kill()
        tunnel = ngrok.connect(6969)
        print(f"Ngrok URL: {tunnel.public_url}")
        # !uv run $prerelease $runpice --listen-port 6969
    except Exception as e:  # noqa: BLE001
        print(f"Error starting ngrok: {e}")
elif method == "cloudflared":
    # !curl -LO https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
    # !dpkg -i cloudflared-linux-amd64.deb
    clear_output()
    # !rm -rf nohup.out
    # !nohup cloudflared tunnel --url localhost:6969 &
    clear_output()
    time.sleep(10)
    cloudflare_url = !grep -oE "https://[a-zA-Z0-9.-]+\.trycloudflare\.com" nohup.out
    print(f"URVC Public URL: {cloudflare_url}")
    # !uv run $prerelease $runpice --listen-port 6969
elif method == "localtunnel":
    # !npm install -g localtunnel &>/dev/null
    Path("url.txt").open("w", encoding="utf-8").close()
    # !lt --port 6969 >> url.txt 2>&1 &
    time.sleep(2)
    endpoint_ip = (
        request.urlopen("https://ipv4.icanhazip.com").read().decode("utf8").strip("\n")
    )
    tunnel_url = (
        Path("url.txt").read_text(encoding="utf-8").replace("your url is: ", "")
    )
    print(f"Share Link: {tunnel_url}")
    password_endpoint_widget = widgets.Text(
        value=endpoint_ip,
        description="Password IP:",
        disabled=True,
    )
    i_display(password_endpoint_widget)
    # !uv run $prerelease $runpice --listen-port 6969
# Out:
# Bytecode compiled 19354 files in 1.41s
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://754f642127292ec734.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 100% 1/1 [00:19<00:00, 19.54s/it]
# [~] Extracting pitch features...
# 100% 9/9 [00:02<00:00,  3.98it/s]
# [~] Extracting audio embeddings...
# 100% 9/9 [00:01<00:00,  7.04it/s]
# /content/HRVC/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /content/HRVC/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Ram | epoch=1 | time=15:45:50 | training_speed=0:00:52 | best avg-gen-loss=16.550 (epoch 1)
# Ram | epoch=2 | time=15:45:55 | training_speed=0:00:05 | best avg-gen-loss=14.771 (epoch 2)
# Ram | epoch=3 | time=15:46:01 | training_speed=0:00:05 | best avg-gen-loss=14.475 (epoch 3)
# Ram | epoch=4 | time=15:46:07 | training_speed=0:00:05 | best avg-gen-loss=13.610 (epoch 4)
# Ram | epoch=5 | time=15:46:13 | training_speed=0:00:05 | best avg-gen-loss=13.610 (epoch 4)
# Ram | epoch=6 | time=15:46:18 | training_speed=0:00:05 | best avg-gen-loss=12.658 (epoch 6)
# Ram | epoch=7 | time=15:46:24 | training_speed=0:00:05 | best avg-gen-loss=12.302 (epoch 7)
# Ram | epoch=8 | time=15:46:30 | training_speed=0:00:05 | best avg-gen-loss=12.302 (epoch 7)
# Ram | epoch=9 | time=15:46:35 | training_speed=0:00:05 | best avg-gen-loss=12.302 (epoch 7)
# Ram | epoch=10 | time=15:46:41 | training_speed=0:00:05 | best avg-gen-loss=12.160 (epoch 10)
# Ram | epoch=11 | time=15:47:48 | training_speed=0:00:05 | best avg-gen-loss=12.160 (epoch 10)
# Ram | epoch=12 | time=15:47:54 | training_speed=0:00:06 | best avg-gen-loss=11.874 (epoch 12)
# Ram | epoch=13 | time=15:48:00 | training_speed=0:00:05 | best avg-gen-loss=11.874 (epoch 12)
# Ram | epoch=14 | time=15:48:06 | training_speed=0:00:05 | best avg-gen-loss=11.874 (epoch 12)
# Ram | epoch=15 | time=15:48:12 | training_speed=0:00:05 | best avg-gen-loss=11.874 (epoch 12)
# Ram | epoch=16 | time=15:48:18 | training_speed=0:00:05 | best avg-gen-loss=11.874 (epoch 12)
# Ram | epoch=17 | time=15:48:24 | training_speed=0:00:05 | best avg-gen-loss=11.869 (epoch 17)
# Ram | epoch=18 | time=15:48:30 | training_speed=0:00:05 | best avg-gen-loss=11.740 (epoch 18)
| training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=432 | time=16:53:25 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=433 | time=16:53:30 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=434 | time=16:53:36 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=435 | time=16:53:42 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=436 | time=16:53:48 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=437 | time=16:53:54 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=438 | time=16:54:00 | training_speed=0:00:06 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=439 | time=16:54:06 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=440 | time=16:54:12 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=441 | time=16:54:43 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=442 | time=16:54:49 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=443 | time=16:54:55 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=444 | time=16:55:01 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=445 | time=16:55:06 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=446 | time=16:55:12 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=447 | time=16:55:18 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=448 | time=16:55:24 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=449 | time=16:55:30 | training_speed=0:00:06 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=450 | time=16:55:36 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=451 | time=16:56:48 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=452 | time=16:56:54 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=453 | time=16:57:00 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=454 | time=16:57:05 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=455 | time=16:57:11 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=456 | time=16:57:17 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=457 | time=16:57:23 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=458 | time=16:57:29 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=459 | time=16:57:35 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=460 | time=16:57:41 | training_speed=0:00:06 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=461 | time=16:58:24 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=462 | time=16:58:29 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=463 | time=16:58:35 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=464 | time=16:58:41 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=465 | time=16:58:47 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=466 | time=16:58:53 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=467 | time=16:58:58 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=468 | time=16:59:04 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=469 | time=16:59:10 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=470 | time=16:59:16 | training_speed=0:00:06 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=471 | time=16:59:58 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=472 | time=17:00:04 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=473 | time=17:00:09 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=474 | time=17:00:15 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=475 | time=17:00:21 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=476 | time=17:00:27 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=477 | time=17:00:33 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=478 | time=17:00:39 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=479 | time=17:00:45 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=480 | time=17:00:51 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=481 | time=17:01:41 | training_speed=0:00:06 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=482 | time=17:01:47 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=483 | time=17:01:52 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=484 | time=17:01:58 | training_speed=0:00:05 | best avg-gen-loss=9.666 (epoch 354)
# Ram | epoch=485 | time=17:02:04 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=486 | time=17:02:10 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=487 | time=17:02:16 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=488 | time=17:02:21 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=489 | time=17:02:27 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=490 | time=17:02:33 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=491 | time=17:03:17 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=492 | time=17:03:22 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=493 | time=17:03:28 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=494 | time=17:03:34 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=495 | time=17:03:40 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=496 | time=17:03:46 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=497 | time=17:03:52 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=498 | time=17:03:58 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=499 | time=17:04:04 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Ram | epoch=500 | time=17:04:09 | training_speed=0:00:05 | best avg-gen-loss=9.338 (epoch 485)
# Training has been successfully completed with 500 epoch(s), 2000 step(s) and 10.271 average generator loss.
# Lowest average generator loss: 9.338 at epoch 485
# Traceback (most recent call last):
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2116, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1623, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2502, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/web/common.py", line 75, in _wrapped_fn
#     raise gr.Error(str(msg)) from None
# gradio.exceptions.Error: 'No files selected.'
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# Traceback (most recent call last):
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2116, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1623, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2502, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/web/common.py", line 527, in update_output_name
#     output_name = fn(*args, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/core/generate/speech.py", line 412, in get_mixed_speech_track_name
#     source_name = source_path.stem if source_path.is_file() else "Text"
#                                       ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 892, in is_file
#     return S_ISREG(self.stat().st_mode)
#                    ^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 840, in stat
#     return os.stat(self, follow_symlinks=follow_symlinks)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 36] File name too long: '\nDance move detected.\nDancing is an essential form of expression.\n\nWhen humans dance together, it can become a MOVEMENT that impacts all involved, potentially shaping human history and society.\n\nA DANCE PARTY MOVEMENT requires someone to take the initial step onto the dance floor.\n\nOthers may watch with curiosity, perhaps even amusement or envy, while the lone Dancer persists with their trail-blazing moves.\n\nYet a Movement cannot exist without The First Follower.\n'
# Traceback (most recent call last):
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2116, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1623, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2502, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/web/common.py", line 527, in update_output_name
#     output_name = fn(*args, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/core/generate/speech.py", line 412, in get_mixed_speech_track_name
#     source_name = source_path.stem if source_path.is_file() else "Text"
#                                       ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 892, in is_file
#     return S_ISREG(self.stat().st_mode)
#                    ^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 840, in stat
#     return os.stat(self, follow_symlinks=follow_symlinks)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 36] File name too long: '\nDance move detected.\nDancing is an essential form of expression.\n\nWhen humans dance together, it can become a MOVEMENT that impacts all involved, potentially shaping human history and society.\n\nA DANCE PARTY MOVEMENT requires someone to take the initial step onto the dance floor.\n\nOthers may watch with curiosity, perhaps even amusement or envy, while the lone Dancer persists with their trail-blazing moves.\n\nYet a Movement cannot exist without The First Follower.\n'
# [~] Converting text using Edge TTS...
# Traceback (most recent call last):
#   File "/content/HRVC/src/ultimate_rvc/web/common.py", line 70, in _wrapped_fn
#     res = fn(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/core/generate/speech.py", line 609, in run_pipeline
#     speech_track = run_edge_tts(
#                    ^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/core/generate/speech.py", line 231, in run_edge_tts
#     source_is_file = source_path.is_file()
#                      ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 892, in is_file
#     return S_ISREG(self.stat().st_mode)
#                    ^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 840, in stat
#     return os.stat(self, follow_symlinks=follow_symlinks)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 36] File name too long: '\nDance move detected.\nDancing is an essential form of expression.\n\nWhen humans dance together, it can become a MOVEMENT that impacts all involved, potentially shaping human history and society.\n\nA DANCE PARTY MOVEMENT requires someone to take the initial step onto the dance floor.\n\nOthers may watch with curiosity, perhaps even amusement or envy, while the lone Dancer persists with their trail-blazing moves.\n\nYet a Movement cannot exist without The First Follower.\n'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2116, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1623, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2502, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/web/common.py", line 77, in _wrapped_fn
#     raise gr.Error(str(e)) from e
# gradio.exceptions.Error: "[Errno 36] File name too long: '\\nDance move detected.\\nDancing is an essential form of expression.\\n\\nWhen humans dance together, it can become a MOVEMENT that impacts all involved, potentially shaping human history and society.\\n\\nA DANCE PARTY MOVEMENT requires someone to take the initial step onto the dance floor.\\n\\nOthers may watch with curiosity, perhaps even amusement or envy, while the lone Dancer persists with their trail-blazing moves.\\n\\nYet a Movement cannot exist without The First Follower.\\n'"
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
# [~] Converting text using Edge TTS...
# [~] Converting speech using RVC...
# [~] Mixing speech track...
